# %% [markdown]
# <a href="https://colab.research.google.com/github/marianabsctba/AT_Fundamentos_Python/blob/main/Quest%C3%A3o13_A_B_AT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#13) Obtenha, usando requests ou urllib, o conteúdo sobre as PyLadies no link http://brasil.pyladies.com/about e:
#A) Conte todas as palavras no corpo da página, e indique quais palavras apareceram apenas uma vez.
#B) Conte quantas vezes apareceu a palavra ladies no conteúdo da página.


import re
import requests
from bs4 import BeautifulSoup
import pandas as pd
from functools import reduce

r = requests.get('http://brasil.pyladies.com/about')
r.encoding = 'utf-8'
file = r.text
soup = BeautifulSoup(file, "lxml")

whitelist = [
  'p'
]
text_elements = ''.join([t for t in soup.find_all(text=True) if t.parent.name in whitelist])

place = re.sub('[^a-zA-ZáàâãéèêíïóôõöúçñÁÀÂÃÉÈÍÏÓÔÕÖÚÇÑ\s]', '', text_elements).upper()


wordlist = place.split()
wordfreq = {}
for w in wordlist:
    wordfreq[w] = wordlist.count(w)

def prints():
    distintas = len(wordfreq)
    total = sum([wordfreq[k] for k in wordfreq ])
    
    print('Quantidade de ladies: {}'.format(wordfreq['LADIES']))
    print(f'Quantidade de palavras distintas: {distintas}')
    print(f'Total de palavras: {total}')
    
    print('Palavras que apareceram somente uma vez:')
    
    for k in wordfreq:
      if wordfreq[k]==1:
        print(f'{k}')

prints()
# Out:
# Quantidade de ladies: 2
# Quantidade de palavras distintas: 158
# Total de palavras: 247
# Palavras que apareceram somente uma vez:
# PYLADIES
# COMUNIDADE
# MUNDIAL
# TRAZIDA
# AO
# INSTIGAR
# MULHERES
# ENTRAREM
# NA
# TECNOLÓGICA
# MUDAR
# ESSA
# REALIDADE
# GAROTAS
# RICA
# FANTÁSTICA
# COMO
# COMPUTAÇÃO
# OLHE
# TEMOS
# MUITA
# HISTÓRIA
# NESSE
# CAMPO
# VIU
# NÓS
# PERCEBEMOS
# HAVIAM
# MOTIVOS
# SERMOS
# SALAS
# CURSOS
# UNIVERSITÁRIOS
# TÉCNICOS
# INFORMÁTICA
# RESOLVEMOS
# ORGANIZAR
# DAR
# JEITINHO
# NISSO
# ENCONTRAMOS
# OUTRAS
# REUNIAM
# NOME
# DA
# PROGRAMAÇÃO
# FALAVAM
# ABSTRAÇÃO
# JEITO
# SABEM
# FALAR
# MOSTRAR
# ÀS
# HÁ
# LIMITES
# SUA
# CAPACIDADE
# INTELECTUAL
# DELAS
# ESCREVER
# FAÇAM
# ISSO
# DESENVOLVER
# SUPER
# SISTEMAS
# EMBARCADOS
# DESENVOLVAM
# QUEREM
# BRINCAR
# FAZENDO
# ALGUMAS
# SCRIPT
# BRINQUEM
# REVOLUCIONAR
# MESMO
# SEM
# TER
# SEU
# FONTE
# REVOLUCIONEM
# POR
# VOCÊS
# SÃO
# CAPAZES
# SEGREGAR
# CONTRÁRIO
# CRIAR
# AMBIENTE
# SEJAM
# ATRAÍDAS
# PELA
# ELAS
# VEJAM
# PENSEM
# EU
# ESTAR
# AÍ
# PARTICIPAR
# DOJO
# MUITO
# LEGAL
# EXPERIÊNCIA
# REPETIR
# VEZES
# ALÉM
# APRENDER
# FORMA
# BEM
# DIFERENTE
# RÁPIDA
# PUDE
# AMIZADES
# CONHECER
# MELHOR
# ESSE
# GRANDE
# DIVERTIDO
